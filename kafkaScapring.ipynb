# %% [markdown]
# <a href="https://colab.research.google.com/github/marcoDev1415/pythonBasico/blob/main/kafkaScapring.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import gspread
from bs4 import BeautifulSoup
import pprint

import time

#---------------------------- Funciones ---------------------------------

def Borrarelemntos(diccionarioTem):     # Esta funcion eliminara codigo html no necesario de la pagina principal

  for contador in range(4):   
   diccionarioTem.pop(0)
     

  return diccionarioTem


def AgregarEspacioTopicos(lista):
  
  
   
  valores=topicos.index('/topic/resultado-verificaciones-topic')


  return valores


#----------------------------- Variables --------------------------------

diccionarioA= []

diccionarioB=[]   #Este diccionario guardara los elementos de la pagina topicos

consumers = []

valores_consumers = []

topicos = []
url="https://monitor-kafka.devops.tijuana.mesh-servicios-fnd.mx"


#-------------------------------------------------------------------------

p2=requests.get(url)

p2.status_code

#print(p2.text)

p2.headers
p2.request.headers  #saber version de python y asi informar al servidor

soup=BeautifulSoup(p2.text,'lxml')

diccionarioA=soup.find('div',attrs={'id':'topics'}).find_all('a')


diccionarioA = Borrarelemntos(diccionarioA)


#pprint.pprint(diccionarioA)


#print(url+urltemporal)
#print(len(diccionarioA))

#-------------------------- Fase dos moviendo a paginas de topicos ----------------


for contador in range(0,82):
     
  urltemporal=diccionarioA[contador].get('href')
  topicos.append(urltemporal)
  p3=requests.get(url+urltemporal)
  p3.status_code
  codigoHtml=BeautifulSoup(p3.text,'lxml')
  #print(url+urltemporal) sirve para ver el url compuesto
  

  diccionarioB= codigoHtml.find('table',attrs={'id':'consumers-table'}).find_all('td')
 

  if len(diccionarioB)==0 :
   valores_consumers.append('SC')
   diccionarioB.clear()
  else:
    for contador in range(0,len(diccionarioB)):

      temporal= diccionarioB[contador].get_text()
      
      if(temporal.isdigit() ==  True):
        valores_consumers.append(temporal)
      else:
        consumers.append(temporal)
    diccionarioB.clear()

print('valores consumers: ',len(valores_consumers))
print('consumers: ',len(consumers))
print('topicos: ',len(topicos))



#----------------------------Topicos-------------------------------------------



# -------------------------- imprimir en archivo --------------------------------


gc = gspread.service_account(filename='prueba-314923-c061f25ebb0e.json')

# Abrir por titulo
sh = gc.open("vitacora")

# Seleccionar primera hoja
worksheet = sh.get_worksheet(0)

# Introducir datos


celda= input('INGRESA LA CELDA DONDE SE PONDRA EL REGISTO: ')
inicio=3
for contador in range(0,len(valores_consumers)):
  inicio=inicio+1

 
  worksheet.update(celda+str(inicio),valores_consumers[contador])
  time.sleep(1.5)
# Out:
# valores consumers:  109
# consumers:  70
# topicos:  82
# INGRESA LA CELDA DONDE SE PONDRA EL REGISTO: d

# %%
import requests
import gspread
from bs4 import BeautifulSoup
import pprint

import time

#---------------------------- Funciones ---------------------------------

def Borrarelemntos(diccionarioTem):     # Esta funcion eliminara codigo html no necesario de la pagina principal

  for contador in range(4):   
   diccionarioTem.pop(0)
     

  return diccionarioTem


def AgregarEspacioTopicos(lista):
  
  
  valores=topicos.index('/topic/resultado-verificaciones-topic')


  return valores


#----------------------------- Variables --------------------------------

diccionarioA= []

diccionarioB=[]   #Este diccionario guardara los elementos de la pagina topicos

consumers = []

valores_consumers = []

topicos = []
url="https://monitor-kafka.devops.tijuana.mesh-servicios-fnd.mx"


#-------------------------------------------------------------------------

p2=requests.get(url)

p2.status_code

#print(p2.text)

p2.headers
p2.request.headers  #saber version de python y asi informar al servidor

soup=BeautifulSoup(p2.text,'lxml')

diccionarioA=soup.find('div',attrs={'id':'topics'}).find_all('a')


diccionarioA = Borrarelemntos(diccionarioA)


#pprint.pprint(diccionarioA)


#print(url+urltemporal)
#print(len(diccionarioA))

#-------------------------- Fase dos moviendo a paginas de topicos ----------------


for contador in range(0,82):
     
  urltemporal=diccionarioA[contador].get('href')
  topicos.append(urltemporal)
  p3=requests.get(url+urltemporal)
  p3.status_code
  codigoHtml=BeautifulSoup(p3.text,'lxml')
  #print(url+urltemporal) sirve para ver el url compuesto
  

  diccionarioB= codigoHtml.find('table',attrs={'id':'consumers-table'}).find_all('td')
 

  if len(diccionarioB)==0 :
   valores_consumers.append('SC')
   diccionarioB.clear()
  else:
    for contador in range(0,len(diccionarioB)):

      temporal= diccionarioB[contador].get_text()
      
      if(temporal.isdigit() ==  True):
        valores_consumers.append(temporal)
      else:
        consumers.append(temporal)
    diccionarioB.clear()

print('valores consumers: ',len(valores_consumers))
print('consumers: ',len(consumers))
print('topicos: ',len(topicos))



#----------------------------Topicos-------------------------------------------


# -------------------------- imprimir en archivo --------------------------------


gc = gspread.service_account(filename='prueba-314923-2efa95c77f2a.json')

# Abrir por titulo
sh = gc.open("vitacora")

# Seleccionar primera hoja
worksheet = sh.get_worksheet(0)

# Introducir datos


celda= input('INGRESA LA CELDA DONDE SE PONDRA EL REGISTRO: ')
inicio=3

contadorparticionado=round(len(valores_consumers)/2)

for contador in range(0,contadorparticionado):
  inicio=inicio+1
 

  worksheet.update(celda+str(inicio),valores_consumers[contador])
  time.sleep(1.2) 
  memoriacontador=contador
  


for contador in range(memoriacontador,len(valores_consumers)):
  inicio=inicio+1
  
  time.sleep(1.0) 
  worksheet.update(celda+str(inicio),valores_consumers[contador])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-1d301badd61e> in <module>()
#      42 #-------------------------------------------------------------------------
#      43
# ---> 44 p2=requests.get(url)
#      45
#      46 p2.status_code
#
# /usr/local/lib/python3.7/dist-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# /usr/local/lib/python3.7/dist-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ...
